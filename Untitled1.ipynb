# %% [markdown]
# <a href="https://colab.research.google.com/github/wostook/NLP/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install imbalanced-learn==0.5.0
# !pip install h2o4gpu

# %%
import h2o4gpu as sklearn
from sklearn.naive_bayes import GaussianNB
import pandas as pd
import seaborn as sns
from time import time
import numpy as np
import sys, os
from time import time
from imblearn.over_sampling import SMOTE,KMeansSMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV 
from sklearn.model_selection import StratifiedShuffleSplit 

#import h2o4gpu as sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, average_precision_score, precision_recall_curve
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/My Drive/app/creditcard.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.head(3)
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
#
# [3 rows x 31 columns]

# %%
data.describe().T
# Out:
#            count          mean  ...            75%            max
# Time    284807.0  9.481386e+04  ...  139320.500000  172792.000000
# V1      284807.0  3.919560e-15  ...       1.315642       2.454930
# V2      284807.0  5.688174e-16  ...       0.803724      22.057729
# V3      284807.0 -8.769071e-15  ...       1.027196       9.382558
# V4      284807.0  2.782312e-15  ...       0.743341      16.875344
# V5      284807.0 -1.552563e-15  ...       0.611926      34.801666
# V6      284807.0  2.010663e-15  ...       0.398565      73.301626
# V7      284807.0 -1.694249e-15  ...       0.570436     120.589494
# V8      284807.0 -1.927028e-16  ...       0.327346      20.007208
# V9      284807.0 -3.137024e-15  ...       0.597139      15.594995
# V10     284807.0  1.768627e-15  ...       0.453923      23.745136
# V11     284807.0  9.170318e-16  ...       0.739593      12.018913
# V12     284807.0 -1.810658e-15  ...       0.618238       7.848392
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Plot number of fraud and legit records
counts=data['Class'].value_counts()
print('There are {} fraud intances ({:.2f}%)'.format(counts[1],(100*counts[1]/data.shape[0])))
print('There are {} non-fraud intances ({:.2f}%)'.format(counts[0],(100*counts[0]/data.shape[0])))
sns.countplot(data['Class'])
plt.title("Class distribution")
plt.xlabel("Class")
plt.ylabel("Frequency");
# Out:
# There are 492 fraud intances (0.17%)
# There are 284315 non-fraud intances (99.83%)

# %%
sns.set()

# %%
#most of features are anonymous, however there are twe features that remained raw - Time and Amount
fig,ax=plt.subplots(sharex=True,sharey=True,figsize=(10,6))
sns.scatterplot(data[data['Class']==0]['Time'],data[data['Class']==0]['Amount'],ax=ax,alpha=0.2)
sns.scatterplot(data[data['Class']==1]['Time'],data[data['Class']==1]['Amount'],ax=ax)
plt.xlabel('Time');
plt.title('Time distibution');

# %% [markdown]
# Since most of features were probably scaled before calculating PCA, to streamlinefurther computations, one may need to scale Time and Amount features

# %%
#Amount clearly contains some outliers, for that reason we will use RobustScaler 
from sklearn.preprocessing import RobustScaler,StandardScaler
data['Amount_scaled'] = RobustScaler().fit_transform(data['Amount'].values.reshape(-1,1))
data['Time_scaled']=StandardScaler().fit_transform(data['Time'].values.reshape(-1,1))

data.drop(columns=['Amount','Time'],inplace=True)

# %% [markdown]
# Anova

# %%
from sklearn.feature_selection import f_classif

# %%
X=data.drop(columns='Class')
y=data['Class']
f,pval=f_classif(X,y)

# %%
anova=pd.DataFrame(pval,index=X.columns,columns=['pval'])
anova[anova['pval']>0.05]
# Out:
#          pval
# V22  0.667360
# V23  0.151860
# V25  0.077525

# %%
ordered_indx=anova.sort_values(by='pval',ascending=True).index

# %%
fig, ax = plt.subplots(8, 4, figsize=(20, 40))
for variable, subplot in zip(ordered_indx, ax.flatten()):
    sns.distplot(data[data['Class']==0][variable],bins=30,ax=subplot)
    sns.distplot(data[data['Class']==1][variable],bins=30,ax=subplot)

# %%
corFR=data[data['Class']==1].corr()
corNFR=data[data['Class']==0].corr()
cmap = sns.diverging_palette(240,20, as_cmap=True)
mask = np.zeros_like(corFR)
mask[np.triu_indices_from(mask)] = True

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(22,8))
a=sns.heatmap(corNFR, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=0.15,ax=ax1)
a.set_facecolor('white')
a.set_title('Non-fraudulent data',fontsize=15)
b=sns.heatmap(corFR, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=0.15,ax=ax2)
b.set_facecolor('white')
b.set_title('Fraudulent data',fontsize=15);

# %%
def get_correlated_plot(dataset,treshold=0.85):
    cor_raw=dataset.corr()
    cor_mask=cor_raw.where(np.triu(np.ones(cor_raw.shape)).astype(np.bool))
    l=[]
    for i in cor_mask.index.values:
        for col in cor_mask.columns.values:
            if (cor_mask.loc[i,col]>treshold or cor_mask.loc[i,col]<-treshold) and i!=col:
                l.append((i,col))
                
   
    ncols=4
    nrows=[len(l)//ncols if len(l)%ncols==0 else len(l)//ncols+1][0]
    fig, ax = plt.subplots(nrows, ncols, figsize=(15, 15))
    fraud=data[data['Class']==1]
    fraud=fraud.iloc[:5000]
    nonfraud=data[data['Class']==0]
    nonfraud=nonfraud.iloc[:5000]
    for variable, subplot in zip(l, ax.flatten()):
        sns.scatterplot(nonfraud[variable[0]],nonfraud[variable[1]],label='non-fraud',alpha=0.3,ax=subplot)
        sns.scatterplot(fraud[variable[0]],fraud[variable[1]],label='fraud',alpha=0.7,ax=subplot)
        plt.xlabel('Time');
        plt.tight_layout()

# %%
get_correlated_plot(data[data['Class']==1],treshold=0.85)

# %%
from sklearn.manifold import TSNE
start=time()
X_embedded = TSNE(n_components=2).fit_transform(X.iloc[:3000])
end=time()
search_time = (end-start)
search_time
# Out:
# 21.699456930160522

# %%
start=time()
plt.figure(figsize=(9,7))
sns.scatterplot(X_embedded[:,1],X_embedded[:,0],hue=data.iloc[:3000]['Class'],alpha=0.7)
plt.xlabel('label')
plt.ylabel('label')
plt.title('t-SNE',fontsize=15);
end=time()

# %%
from sklearn.cluster import KMeans

# %%
start=time()
cluster_label=KMeans(10,random_state=0).fit(data.drop(columns=['Class'])).labels_
end=time()

# %%
data['Clusters']=cluster_label
search_time = (end-start)
search_time
# Out:
# 23.928298473358154

# %%
data.groupby('Clusters')['Class'].mean()
# Out:
# Clusters
# 0    0.001435
# 1    0.004960
# 2    0.000625
# 3    0.003080
# 4    0.002990
# 5    0.000000
# 6    0.000000
# 7    0.000797
# 8    0.038020
# 9    0.001157
# Name: Class, dtype: float64

# %%
data.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class',
#        'Amount_scaled', 'Time_scaled', 'Clusters'],
#       dtype='object')

# %%
data['Cluster10']=data['Clusters'].apply(lambda x:1 if x==9 else 0)
data.drop(columns=['Clusters'],inplace=True)

# %%
ratios=[]
for n in range(2,10):
    cluster_label=KMeans(n).fit(X).labels_
    data['Clusters']=cluster_label
    ratio=data.groupby('Clusters')['Class'].mean().max()
    ratios.append(ratio)

# %%
ratios
# Out:
# [0.0023900191734128676,
#  0.022939677145284623,
#  0.033327914160299135,
#  0.03526361279170268,
#  0.03568904593639576,
#  0.03575221238938053,
#  0.03560343253605989,
#  0.8222222222222222]

# %%
from sklearn.cluster import KMeans

kmean_scores=[KMeans(n).fit(X).inertia_ for n in range(2,15)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-9d7dd7993786> in <module>()
#       1 from sklearn.cluster import KMeans
#       2
# ----> 3 kmean_scores=[KMeans(n).fit(X).inertia_ for n in range(2,15)]
#
# <ipython-input-26-9d7dd7993786> in <listcomp>(.0)
#       1 from sklearn.cluster import KMeans
#       2
# ----> 3 kmean_scores=[KMeans(n).fit(X).inertia_ for n in range(2,15)]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     967                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     968                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 969                 return_n_iter=True)
#     970         return self
#     971
#
# ...

# %%
pd.DataFrame(kmean_scores).plot()

# %%
y=data['Class']
X=data.drop(columns=['Class','V22','V23','V25'])
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score

scoring = {'accuracy' : make_scorer(accuracy_score), 
           'precision' : make_scorer(precision_score),
           'recall' : make_scorer(recall_score), 
           'f1_score' : make_scorer(f1_score)}

# %%
import xgboost as xgb

# %%
params = {}
params['objective'] = 'binary:logistic'
params['eta'] = 0.039
params['silent'] = True
params['max_depth'] = 2
params['subsample'] = 0.8
params['colsample_bytree'] = 0.9
params['eval_metric'] = 'auc'

# %%
model = xgb.train(params, 
                dtrain=X_train, 
                MAX_ROUNDS, 
                early_stopping_rounds=EARLY_STOP, 
                maximize=True, 
                verbose_eval=VERBOSE_EVAL)
# Out:
#   File "<ipython-input-128-bf8d9460cf8f>", line 3
#     MAX_ROUNDS,
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,test_size=0.2, random_state=0)

# %%
X_train_smote, y_train_smote = SMOTE(sampling_strategy='minority',random_state=3).fit_resample(X_train, y_train)

# %%
X_train_KMsmote, y_train_KMsmote = KMeansSMOTE(sampling_strategy='minority',kmeans_estimator=60,random_state=1).fit_resample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-599124472780> in <module>()
# ----> 1 X_train_KMsmote, y_train_KMsmote = KMeansSMOTE(sampling_strategy='minority',kmeans_estimator=60,random_state=1).fit_resample(X_train, y_train)
#
# /usr/local/lib/python3.6/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      82             self.sampling_strategy, y, self._sampling_type)
#      83
# ---> 84         output = self._fit_resample(X, y)
#      85
#      86         if binarize_y:
#
# /usr/local/lib/python3.6/dist-packages/imblearn/over_sampling/_smote.py in _fit_resample(self, X, y)
#    1234     # FIXME: rename _sample -> _fit_resample in 0.6
#    1235     def _fit_resample(self, X, y):
# -> 1236         return self._sample(X, y)
#    1237
#    1238     def _sample(self, X, y):
#
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
confusion_matrix
# Out:
# <function sklearn.metrics._classification.confusion_matrix(y_true, y_pred, *, labels=None, sample_weight=None, normalize=None)>

# %%
gnb = GaussianNB()
lr=LogisticRegression(max_iter=1000)
SKF=StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
scores=cross_val_score(lr,X_train,y_train,scoring=make_scorer(f1_score))
print('Average score: {:.2f} with SD: {:.2f}'.format(np.mean(scores),np.std(scores)))
# Out:
# Average score: 0.77 with SD: 0.02

# %%
lr=LogisticRegression(max_iter=1000).fit(X_train,y_train)
print(confusion_matrix(y_test,lr.predict(X_test)))
# Out:
# [[56854    10]
#  [   36    62]]

# %%
print(classification_report(y_test,lr.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.86      0.63      0.73        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.82      0.86     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
start=time()

model = LogisticRegression(max_iter=1000)
lr=LogisticRegression(max_iter=1000)
SKF=StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
scores=cross_val_score(model,X_train,y_train,scoring=make_scorer(f1_score))
end=time()
print('Average score: {:.2f} with SD: {:.2f}'.format(np.mean(scores),np.std(scores)))

model = LogisticRegression(max_iter=1000).fit(X_train,y_train)
print(confusion_matrix(y_test,model.predict(X_test)))
print(classification_report(y_test,model.predict(X_test)))

search_time = (end-start)
search_time
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Average score: 0.73 with SD: 0.05
# ...

# %%
model = LogisticRegression(max_iter=1000)
lr=LogisticRegression(max_iter=1000)
SKF=StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
scores=cross_val_score(model,X_train,y_train,scoring=make_scorer(f1_score))
print('Average score: {:.2f} with SD: {:.2f}'.format(np.mean(scores),np.std(scores)))

model = LogisticRegression(max_iter=1000).fit(X_train,y_train)
print(confusion_matrix(y_test,model.predict(X_test)))
print(classification_report(y_test,model.predict(X_test)))
# Out:
# Average score: 0.77 with SD: 0.03
# [[56855     9]
#  [   35    63]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.88      0.64      0.74        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.82      0.87     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model = LogisticRegression(max_iter=1000)
lr=LogisticRegression(max_iter=1000)
SKF=StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
scores=cross_val_score(model,X_train_smote,y_train_smote,scoring=make_scorer(f1_score))
print('Average score: {:.2f} with SD: {:.2f}'.format(np.mean(scores),np.std(scores)))

model = LogisticRegression(max_iter=1000).fit(X_train_smote,y_train_smote)
print(confusion_matrix(y_test,model.predict(X_test)))
print(classification_report(y_test,model.predict(X_test)))
# Out:
# Average score: 0.95 with SD: 0.00
# [[55476  1388]
#  [   11    87]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.06      0.89      0.11        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.93      0.55     56962
# weighted avg       1.00      0.98      0.99     56962

# %%
model = LogisticRegression(max_iter=1000)
lr=LogisticRegression(max_iter=1000)
SKF=StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
scores=cross_val_score(model,X_train_KMsmote,y_train_KMsmote,scoring=make_scorer(f1_score))
print('Average score: {:.2f} with SD: {:.2f}'.format(np.mean(scores),np.std(scores)))

model = LogisticRegression(max_iter=1000).fit(X_train_KMsmote,y_train_KMsmote)
print(confusion_matrix(y_test,model.predict(X_test)))
print(classification_report(y_test,model.predict(X_test)))
# Out:
# Average score: 1.00 with SD: 0.00
# [[56846    18]
#  [   21    77]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.81      0.79      0.80        98
#
#     accuracy                           1.00     56962
#    macro avg       0.91      0.89      0.90     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model = LogisticRegression(max_iter=1000)
lr=LogisticRegression(max_iter=1000)
SKF=StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
scores=cross_val_score(model,X_train_KMsmote,y_train_KMsmote,scoring=make_scorer(f1_score))
print('Average score: {:.2f} with SD: {:.2f}'.format(np.mean(scores),np.std(scores)))

model = LogisticRegression(max_iter=1000).fit(X_train_KMsmote,y_train_KMsmote)
print(confusion_matrix(y_test,model.predict(X_test)))
print(classification_report(y_test,model.predict(X_test)))
# Out:
# Average score: 1.00 with SD: 0.00
# [[56845    19]
#  [   20    78]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.80      0.80      0.80        98
#
#     accuracy                           1.00     56962
#    macro avg       0.90      0.90      0.90     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
start=time()

#from sklearn.ensemble import RandomForestClassifier as rfc
rand_f = rfc(random_state=1)
rand_f.fit(X_train, y_train)
y_pred = rand_f.predict(X_test)
end=time()
print(confusion_matrix(y_test,rand_f.predict(X_test)))

print(classification_report(y_test,rand_f.predict(X_test)))

search_time = (end-start)
search_time
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [[56861     3]
#  [   30    68]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.96      0.69      0.80        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.85      0.90     56962
# weighted avg       1.00      1.00      1.00     56962
# 16.376015424728394

# %%
from sklearn.ensemble import RandomForestClassifier as rfc
rand_f = rfc(n_estimators=40, min_samples_split=10, min_samples_leaf=1,
           max_features='auto', max_leaf_nodes=None,
           oob_score=True, n_jobs=-1, random_state=1)
rand_f.fit(X_train_smote, y_train_smote)
y_pred = rand_f.predict(X_test)

print(confusion_matrix(y_test,rand_f.predict(X_test)))

print(classification_report(y_test,rand_f.predict(X_test)))
# Out:
# [[56854    10]
#  [   19    79]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.89      0.81      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.94      0.90      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from xgboost import XGBClassifier

# %%
XGB = XGBClassifier(random_state=1)
XGB.fit(X_train, y_train)
y_pred = XGB.predict(X_test)

print(confusion_matrix(y_test,XGB.predict(X_test)))

print(classification_report(y_test,XGB.predict(X_test)))
# Out:
# [[56861     3]
#  [   23    75]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.96      0.77      0.85        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.88      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
XGB = XGBClassifier(random_state=1)
XGB.fit(X_train_KMsmote, y_train_KMsmote)
y_pred = XGB.predict(X_test)

print(confusion_matrix(y_test,XGB.predict(X_test)))

print(classification_report(y_test,XGB.predict(X_test)))
# Out:
# [[56856     8]
#  [   24    74]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.90      0.76      0.82        98
#
#     accuracy                           1.00     56962
#    macro avg       0.95      0.88      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
X_train_KMsmote
lr=LogisticRegression(max_iter=1000)
SKF=StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
scores=cross_val_score(lr,X_train_KMsmote,y_train_KMsmote,scoring=make_scorer(f1_score))
print('Average score: {:.2f} with SD: {:.2f}'.format(np.mean(scores),np.std(scores)))

lr=LogisticRegression(max_iter=1000).fit(X_train_KMsmote,y_train_KMsmote)
print(confusion_matrix(y_test,lr.predict(X_test)))

print(classification_report(y_test,lr.predict(X_test)))
# Out:
# Average score: 1.00 with SD: 0.00
# [[56849    15]
#  [   20    78]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.84      0.80      0.82        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.90      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.ensemble import StackingClassifier

estimators = [ ('rf', rfc(n_estimators=40, min_samples_split=10, min_samples_leaf=1,
           max_features='auto', max_leaf_nodes=None,
           oob_score=True, n_jobs=-1, random_state=1)),
              ('lr', LogisticRegression(max_iter=1000))]

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
clf.fit(X_train, y_train)
print(confusion_matrix(y_test,clf.predict(X_test)))

print(classification_report(y_test,clf.predict(X_test)))
# Out:
# [[56860     4]
#  [   27    71]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.95      0.72      0.82        98
#
#     accuracy                           1.00     56962
#    macro avg       0.97      0.86      0.91     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.svm import SVC

# %%
svc=SVC(gamma='auto')
svc.fit(X_train_KMsmote, y_train_KMsmote)
print(confusion_matrix(y_test,svc.predict(X_test)))

print(classification_report(y_test,svc.predict(X_test)))

# %%
svc=SVC(gamma='auto')
svc.fit(X_train_smote, y_train_smote)
print(confusion_matrix(y_test,svc.predict(X_test)))

print(classification_report(y_test,svc.predict(X_test)))

# %%
def train_model(X_train, y_train):
    # Split training for 5-fold validation
    sss = StratifiedShuffleSplit(n_splits=5, random_state=20)
    # Logistic Regression
    model = LogisticRegression(solver='liblinear')
    # Random grid search on hyperparameters
    params = {"penalty": ['l1', 'l2'], 'C': [0.1, 1, 10, 100]}
    '''
    To optimize precision-recall score (average precision score)
    AP summarizes a precision-recall curve as the weighted mean of precisions 
    achieved at each threshold, with the increase in recall from the previous 
    threshold used as the weight
    '''
    scoring = {'ave_prec': 'average_precision'}
    n_iter = 6
    grid_search = RandomizedSearchCV(model, 
                                  params, 
                                  scoring=scoring,
                                  random_state= 50,
                                  refit='ave_prec', 
                                  cv=sss,
                                  n_iter=n_iter,
                                  verbose=1,
                                  n_jobs=-1)
    
    start = time() # start time
    lr_fit = grid_search.fit(X_train, y_train)
    lr_best = grid_search.best_estimator_
    end = time() # end time
    # Calculate training time
    search_time = (end-start)/60.
    print('--'*30)
    print('Took {0:.2f} minutes to find optimal parameters'.format(search_time))
    print('Best parameters for model: {}'.format(lr_fit.best_params_))
    print('Best precision-recall socre from training: {}'.format(lr_fit.best_score_))
    return lr_best

# %%
def predict_test(model, X_test, y_test):
    y_test_pred = model.predict(X_test)
    print("Confusion Matrix")
    print(confusion_matrix(y_test, y_test_pred))
    print("Classification Report")
    print(classification_report(y_test, y_test_pred))
    print('--'*30)
    # Plot precision-recall curve
    # Compute precision-recall pairs for different probability threshold
    precision, recall, _ = precision_recall_curve(y_test, model.decision_function(X_test))
    plt.figure(figsize=(12,6))
    plt.plot(recall, precision, c='b' )
    plt.xlim([-0.05,1.05])
    plt.ylim([-0.05,1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    pr_score = average_precision_score(y_test, model.decision_function(X_test))
    plt.title('Test PR curve: \n Average Precision-Recall Score ={0:0.2f}'.format(pr_score, fontsize=14))
    plt.grid(b=True, which='major', c='g', linestyle='-', alpha=0.2)
    plt.show()

# %%
import numpy as np

# %%
skewed=['V2', 'V23', 'V8', 'V28', 'scaledAmount']
for col in skewed:
    X[col]=np.log1p(X[col])
# Out:
# C:\Users\gorcz\Anaconda3\lib\site-packages\pandas\core\series.py:853: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\gorcz\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
(X['V2']).skew()
# Out:
# -1.824354406749583

# %%
np.abs(X.skew()).sort_values()

# %%
# Separate labels from features
#X = data.loc[:,data.columns!='Class']
#y = data['Class']
# Split train and test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=10)

# %%
# -----------  Train and test imbalanced datasets ----------
model_regular = train_model(X_train, y_train)
predict_test (model_regular, X_test, y_test)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    9.6s finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-e05a44763e81> in <module>
#       1 # -----------  Train and test imbalanced datasets ----------
# ----> 2 model_regular = train_model(X_train, y_train)
#       3 predict_test (model_regular, X_test, y_test)
#
# <ipython-input-5-55d40f9440bc> in train_model(X_train, y_train)
#      25
#      26     start = time() # start time
# ---> 27     lr_fit = grid_search.fit(X_train, y_train)
#      28     lr_best = grid_search.best_estimator_
#      29     end = time() # end time
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
# -----------  SMOTE (Synthetic Minority Over-sampling Technique) ----------
X_train_smote, y_train_smote = KMeansSMOTE(sampling_strategy='minority').fit_resample(X_train, y_train)
model_smote = train_model(X_train_smote, y_train_smote)
predict_test (model_smote, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-a769bdb94cdb> in <module>
#       1 # -----------  SMOTE (Synthetic Minority Over-sampling Technique) ----------
# ----> 2 X_train_smote, y_train_smote = KMeansSMOTE(sampling_strategy='minority').fit_resample(X_train, y_train)
#       3 model_smote = train_model(X_train_smote, y_train_smote)
#       4 predict_test (model_smote, X_test, y_test)
#
# ~\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# ~\Anaconda3\lib\site-packages\imblearn\base.py in _check_X_y(self, X, y, accept_sparse)
# ...
